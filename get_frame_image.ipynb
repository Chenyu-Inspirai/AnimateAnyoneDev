# %%
import cv2
from src.utils.util import get_fps, read_frames

# %%
video_path= '/cephfs/SZ-AI/usr/liuchenyu/HaiLook/Moore-AnimateAnyone/assets/video_clips/tiktok_vlip_0.mp4'

# %%
videos = read_frames(video_path)

# %%
len(videos)
# Out:
# 645

# %%
index =583

videos[index]
# Out:
# <PIL.Image.Image image mode=RGB size=540x960>
